# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
player_data=purchase_data.loc[:, ["Gender", "SN", "Age"]]
unique_values=player_data.drop_duplicates()
count = unique_values["Gender"].count()
total_players=pd.DataFrame({"Total Players":[count]})
total_players.head()
# Out:
#    Total Players
# 0            576

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
unique = len(purchase_data["Item ID"].unique())
unique
# Out:
# 183

# %%
average = purchase_data["Price"].mean()
average
# Out:
# 3.050987179487176

# %%
purchase_count = purchase_data["Purchase ID"].count()
purchase_count
# Out:
# 780

# %%
total = purchase_data["Price"].sum()
total
# Out:
# 2379.77

# %%
summary_table=pd.DataFrame({"Unique Items":[unique], 
                            "Average Price":[average],
                            "Number of Purchases":[purchase_count],
                            "Total Revenue":[total]})
summary_table ["Total Revenue"] = summary_table["Total Revenue"].map("${:,.2f}".format)
summary_table ["Average Price"] = summary_table["Average Price"].map("{:,.2f}".format)
summary_table.head()
# Out:
#    Unique Items Average Price  Number of Purchases Total Revenue
# 0           183          3.05                  780     $2,379.77

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
player_count=unique_values["Gender"].value_counts()
percentage_players=player_count/count*100
gender_demographics=pd.DataFrame({"Total Count":player_count,"Percentage of Players":percentage_players})
gender_demographics=gender_demographics.round(2)
gender_demographics
# Out:
#                        Total Count  Percentage of Players
# Male                           484                  84.03
# Female                          81                  14.06
# Other / Non-Disclosed           11                   1.91

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
purchase_count=purchase_data["Gender"].value_counts()
gender_purchase_total = purchase_data.groupby(["Gender"]).sum()["Price"].rename("Total Purchase Value")
gender_average = purchase_data.groupby(["Gender"]).mean()["Price"].rename("Average Purchase Price")
gender_counts = purchase_data.groupby(["Gender"]).count()["Price"].rename("Purchase Count")
# Calculate Normalized Purchasing (Average Total Purchase per Person)
normalized_total = gender_purchase_total / gender_demographics["Total Count"]
purchasing_analysis=pd.DataFrame({"Purchase Count":gender_counts, "Average Purchase Price":gender_average.map("${:,.2f}".format), "Total Purchase Value":gender_purchase_total.map("${:,.2f}".format),"Average Purchase Total Per Person":normalized_total.map("${:,.2f}".format)})
purchasing_analysis
# Out:
#                        Purchase Count Average Purchase Price  \
# Gender
# Female                            113                  $3.20
# Male                              652                  $3.02
# Other / Non-Disclosed              15                  $3.35
#
#                       Total Purchase Value Average Purchase Total Per Person
# Gender
# Female                             $361.94                             $4.47
# Male                             $1,967.64                             $4.07
# Other / Non-Disclosed               $50.19                             $4.56

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
# Create the bins in which Data will be held
bins = [0, 9, 14, 19, 24, 29, 34, 39, 59]

# Create the names for the four bins
age_ranges = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

unique_values["Age Ranges"] = pd.cut(purchase_data["Age"], bins, labels=age_ranges)
age_demo_totals=unique_values["Age Ranges"].value_counts()
unique_ages=unique_values["Age Ranges"].value_counts()
unique_percent=unique_ages/count*100
age_demo=pd.DataFrame({"Total Count":age_demo_totals, "Percentage of Players":unique_percent.map("{:,.2f}%".format)})
age_demo=age_demo.sort_index()
age_demo
# Out:
# /Users/kaylin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#        Total Count Percentage of Players
# <10             17                 2.95%
# 10-14           22                 3.82%
# 15-19          107                18.58%
# 20-24          258                44.79%
# 25-29           77                13.37%
# 30-34           52                 9.03%
# 35-39           31                 5.38%
# 40+             12                 2.08%

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
# Create the bins in which Data will be held
bins = [0, 9, 14, 19, 24, 29, 34, 39, 59]

# Create the names for the four bins
age_ranges = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

purchase_data["Age Ranges"] = pd.cut(purchase_data["Age"], bins, labels=age_ranges)
bin_purchase_total = purchase_data.groupby(["Age Ranges"]).sum()["Price"].rename("Total Purchase Value")
bin_average = purchase_data.groupby(["Age Ranges"]).mean()["Price"].rename("Average Purchase Price")
bin_counts = purchase_data.groupby(["Age Ranges"]).count()["Price"].rename("Purchase Count")
bin_age_total=unique_values["Age"].count()
bin_total = bin_purchase_total/age_demo_totals
bin_purchasing_analysis=pd.DataFrame({"Purchase Count":bin_counts, "Average Purchase Price":bin_average.map("${:,.2f}".format), "Total Purchase Value":bin_purchase_total.map("${:,.2f}".format),"Average Purchase Total Per Person":bin_total.map("${:,.2f}".format)})
bin_purchasing_analysis=bin_purchasing_analysis.sort_index()
bin_purchasing_analysis
# Out:
#        Purchase Count Average Purchase Price Total Purchase Value  \
# <10                23                  $3.35               $77.13
# 10-14              28                  $2.96               $82.78
# 15-19             136                  $3.04              $412.89
# 20-24             365                  $3.05            $1,114.06
# 25-29             101                  $2.90              $293.00
# 30-34              73                  $2.93              $214.00
# 35-39              41                  $3.60              $147.67
# 40+                13                  $2.94               $38.24
#
#       Average Purchase Total Per Person
# <10                               $4.54
# 10-14                             $3.76
# 15-19                             $3.86
# 20-24                             $4.32
# 25-29                             $3.81
# 30-34                             $4.12
# 35-39                             $4.76
# 40+                               $3.19

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
sn_purchase_total = purchase_data.groupby(["SN"]).sum()["Price"].rename("Total Purchase Value")
sn_average = purchase_data.groupby(["SN"]).mean()["Price"].rename("Average Purchase Price")
sn_counts = purchase_data.groupby(["SN"]).count()["Price"].rename("Purchase Count")
sn_purchasing_analysis=pd.DataFrame({"Purchase Count":sn_counts, "Average Purchase Price":sn_average.map("${:,.2f}".format), "Total Purchase Value":sn_purchase_total.map("${:,.2f}".format)})
sn_purchasing_analysis=sn_purchasing_analysis.sort_values(by=["Purchase Count", "Total Purchase Value"], ascending=False)
sn_purchasing_analysis
# Out:
#                Purchase Count Average Purchase Price Total Purchase Value
# SN
# Lisosia93                   5                  $3.79               $18.96
# Idastidru52                 4                  $3.86               $15.45
# Iral74                      4                  $3.40               $13.62
# Haillyrgue51                3                  $3.17                $9.50
# Aina42                      3                  $3.07                $9.22
# Rarallo90                   3                  $3.02                $9.05
# Aelin32                     3                  $2.99                $8.98
# Lisopela58                  3                  $2.95                $8.86
# Saedaiphos46                3                  $2.94                $8.83
# Chanastnya43                3                  $2.94                $8.82
# Raesty92                    3                  $2.91                $8.73
# Hada39                      3                  $2.86                $8.57
# ...

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
popular_total_value = purchase_data.groupby(["Item ID", "Item Name"]).sum()["Price"].rename("Total Purchase Value")
popular_counts = purchase_data.groupby(["Item ID", "Item Name"]).count()["Price"].rename("Purchase Count")
popular_price = purchase_data.groupby(["Item ID", "Item Name"]).mean()["Price"].rename("ITem Price")
popular_purchasing_analysis=pd.DataFrame({"Purchase Count":popular_counts, "Item Price":popular_price, "Total Purchase Value":popular_total_value.map("${:,.2f}".format)})
popular_purchasing_analysis=popular_purchasing_analysis.sort_values(by=["Purchase Count"], ascending=False)
popular_purchasing_analysis
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 145     Fiery Glass Crusader                                       9
# 108     Extraction, Quickblade Of Trembling Hands                  9
# 82      Nirvana                                                    9
# 19      Pursuit, Cudgel of Necromancy                              8
# 103     Singed Scalpel                                             8
# 75      Brutality Ivory Warmace                                    8
# 72      Winter's Bite                                              8
# 60      Wolf                                                       8
# 59      Lightning, Etcher of the King                              8
# 37      Shadow Strike, Glory of Ending Hope                        8
# 34      Retribution Axe                                            8
# ...

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
popular_purchasing_analysis=popular_purchasing_analysis.sort_values(by=["Total Purchase Value"], ascending=False)
popular_purchasing_analysis
# Out:
#                                                    Purchase Count  Item Price  \
# Item ID Item Name
# 63      Stormfury Mace                                          2        4.99
# 29      Chaos, Ender of the End                                 5        1.98
# 173     Stormfury Longsword                                     2        4.93
# 1       Crucifer                                                3        3.26
# 38      The Void, Vengeance of Dark Magic                       4        2.37
# 143     Frenzied Scimitar                                       6        1.56
# 7       Thorn, Satchel of Dark Souls                            7        1.33
# 18      Torchlight, Bond of Storms                              2        4.65
# 129     Fate, Vengeance of Eternal Justice                      6        1.54
# 166     Thirsty Iron Reaver                                     3        3.07
# 123     Twilight's Carver                                       4        2.28
# ...
